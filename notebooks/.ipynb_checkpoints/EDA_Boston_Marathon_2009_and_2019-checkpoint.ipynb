# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
# %matplotlib inline

# %%
bos09 = pd.read_excel('C:/Users/erinm/Documents/Anderson_Capstone/data/BOS_09_AG.xlsx', sheet_name='bos_09_AG', usecols = ["Bib", "Name", "Age", "M/F", "City", "State", "Country", "Pace", "Official_Time", "Overall", "Gender", "Division", "Race Score", "Age-graded result", "Age-graded place", "Place Difference"])
#parse_dates = ['Official_Time']
#dtype={'Age-graded result':str}, 
bos09.columns = ['Bib', 'Name', 'Age', 'Gender', 'City', 'St', 'Cty', 'Pace', 'Time', 'Overall_Place', 'Gender_Place', 'Division_Place', 'AG_Pct', 'AG_Time', 'AG_Place', 'Place_Diff']
bos09['Year'] = 2009
bos09['Race'] = 'Boston Marathon'
bos09.head()
# Out:
#   Bib               Name  Age Gender           City   St  Cty      Pace  \
# 0   4      Merga, Deriba   28      M    Addis Ababa  NaN  ETH  00:04:55
# 1   5       Rono, Daniel   30      M          Keiyo  NaN  KEN  00:04:57
# 2   2         Hall, Ryan   26      M  Mammoth Lakes   CA  USA  00:04:57
# 3  19    Kebede, Tekeste   27      M    Addis Ababa  NaN  ETH  00:04:57
# 4   7  Cheruiyot, Robert   20      M          Bomet  NaN  KEN  00:04:58
#
#        Time  Overall_Place  Gender_Place  Division_Place    AG_Pct   AG_Time  \
# 0  02:08:42              1             1               1  0.955322  02:08:42
# 1  02:09:32              2             2               2  0.949200  02:09:32
# 2  02:09:40              3             3               3  0.948200  02:09:40
# 3  02:09:49              4             4               4  0.947100  02:09:49
# 4  02:10:06              5             5               5  0.945000  02:10:06
#
#    AG_Place  Place_Diff  Year             Race
# 0         1           0  2009  Boston Marathon
# 1         2           0  2009  Boston Marathon
# 2         3           0  2009  Boston Marathon
# 3         4           0  2009  Boston Marathon
# 4         5           0  2009  Boston Marathon

# %%
bos09.dtypes
# Out:
# Bib                object
# Name               object
# Age                 int64
# Gender             object
# City               object
# St                 object
# Cty                object
# Pace               object
# Time               object
# Overall_Place       int64
# Gender_Place        int64
# Division_Place      int64
# AG_Pct            float64
# AG_Time            object
# AG_Place            int64
# Place_Diff          int64
# Year                int64
# Race               object
# dtype: object

# %%
#bos09['AG_Time'] = pd.to_datetime(bos09['AG_Time'], format='%H%M%S')
#bos09.head()

# %%
bos09.describe()
# Out:
#                 Age  Overall_Place  Gender_Place  Division_Place  \
# count  22853.000000   22853.000000  22853.000000    22853.000000
# mean      40.965913   11424.648755   5909.637334     1567.606222
# std       10.768819    6596.195103   3618.027205     1346.239121
# min       18.000000       1.000000      1.000000        1.000000
# 25%       32.000000    5713.000000   2856.000000      493.000000
# 50%       41.000000   11424.000000   5712.000000     1176.000000
# 75%       48.000000   17137.000000   8568.000000     2276.000000
# max       81.000000   22849.000000  13547.000000     5023.000000
#
#              AG_Pct      AG_Place    Place_Diff     Year
# count  22853.000000  22853.000000  22853.000000  22853.0
# mean       0.605725  11427.000000     -2.351245   2009.0
# std        0.082243   6597.237187   3306.704845      0.0
# min        0.286600      1.000000  -4305.000000   2009.0
# 25%        0.561800   5714.000000  -2325.000000   2009.0
# 50%        0.616900  11427.000000   -531.000000   2009.0
# 75%        0.657200  17140.000000   1469.000000   2009.0
# max        0.955322  22853.000000  19568.000000   2009.0

# %%
bos19 = pd.read_excel('C:/Users/erinm/Documents/Anderson_Capstone/data/BOS_19_AG.xlsx', sheet_name='bos_19_AG', 
                      #dtype={'Age-graded result':str}, 
                      usecols = ["Bib", "Name", "Age", "M/F", "City", "State", "Country", "Pace", "Official_Time", "Overall", "Gender", "Division", "Race Score", "Age-graded result", "Age-graded place", "Place Difference"]
                     )
#parse_dates = ['Official_Time']
bos19.columns = ['Bib', 'Name', 'Age', 'Gender', 'City', 'St', 'Cty', 'Pace', 'Time', 'Overall_Place', 'Gender_Place', 'Division_Place', 'AG_Pct', 'AG_Time', 'AG_Place', 'Place_Diff']
bos19['Year'] = 2019
bos19['Race'] = 'Boston Marathon'

# %%
bos19.head()
# Out:
#   Bib               Name  Age Gender      City   St  Cty      Pace      Time  \
# 0   2  Cherono, Lawrence   30      M   Eldoret  NaN  KEN  00:04:53  02:07:57
# 1   6     Desisa, Lelisa   29      M      Ambo  NaN  ETH  00:04:53  02:07:59
# 2   7  Kipkemoi, Kenneth   34      M   Eldoret  NaN  KEN  00:04:54  02:08:07
# 3   8      Kandie, Felix   32      M      Iten  NaN  KEN  00:04:55  02:08:54
# 4  11    Kirui, Geoffrey   26      M  Keringet  NaN  KEN  00:04:56  02:08:55
#
#    Overall_Place  Gender_Place  Division_Place    AG_Pct          AG_Time  \
# 0              1             1               1  0.960922         02:07:57
# 1              2             2               2  0.960672         02:07:59
# 2              3             3               3  0.962270  02:07:46.245000
# 3              4             4               4  0.954031  02:08:52.453000
# 4              5             5               5  0.953717         02:08:55
#
#    AG_Place  Place_Diff  Year             Race
# 0         2          -1  2019  Boston Marathon
# 1         3          -1  2019  Boston Marathon
# 2         1           2  2019  Boston Marathon
# 3         4           0  2019  Boston Marathon
# 4         5           0  2019  Boston Marathon

# %%
bos19.dtypes
# Out:
# Bib                object
# Name               object
# Age                 int64
# Gender             object
# City               object
# St                 object
# Cty                object
# Pace               object
# Time               object
# Overall_Place       int64
# Gender_Place        int64
# Division_Place      int64
# AG_Pct            float64
# AG_Time            object
# AG_Place            int64
# Place_Diff          int64
# Year                int64
# Race               object
# dtype: object

# %%
#bos19['AG_Time']= pd.to_timedelta(bos19['AG_Time'])
#bos19.dtype

# %%
bos19.describe()
# Out:
#                 Age  Overall_Place  Gender_Place  Division_Place  \
# count  26656.000000   26656.000000  26656.000000    26656.000000
# mean      42.800983   13328.522659   6732.580207     1581.232180
# std       11.538085    7695.107083   3963.111688     1424.997114
# min       18.000000       1.000000      1.000000        1.000000
# 25%       34.000000    6664.750000   3332.750000      491.000000
# 50%       43.000000   13328.500000   6664.500000     1128.000000
# 75%       51.000000   19992.250000   9996.250000     2179.000000
# max       83.000000   26657.000000  14675.000000     5660.000000
#
#              AG_Pct      AG_Place    Place_Diff     Year
# count  26656.000000  26656.000000  26656.000000  26656.0
# mean       0.613954  13328.500000      0.022659   2019.0
# std        0.097246   7695.068724   3783.552247      0.0
# min        0.281791      1.000000  -5307.000000   2019.0
# 25%        0.555000   6664.750000  -2692.250000   2019.0
# 50%        0.627480  13328.500000   -621.000000   2019.0
# 75%        0.680602  19992.250000   1792.500000   2019.0
# max        0.970156  26656.000000  23432.000000   2019.0

# %%
boston = pd.concat([bos09, bos19])
boston.head()
# Out:
#   Bib               Name  Age Gender           City   St  Cty      Pace  \
# 0   4      Merga, Deriba   28      M    Addis Ababa  NaN  ETH  00:04:55
# 1   5       Rono, Daniel   30      M          Keiyo  NaN  KEN  00:04:57
# 2   2         Hall, Ryan   26      M  Mammoth Lakes   CA  USA  00:04:57
# 3  19    Kebede, Tekeste   27      M    Addis Ababa  NaN  ETH  00:04:57
# 4   7  Cheruiyot, Robert   20      M          Bomet  NaN  KEN  00:04:58
#
#        Time  Overall_Place  Gender_Place  Division_Place    AG_Pct   AG_Time  \
# 0  02:08:42              1             1               1  0.955322  02:08:42
# 1  02:09:32              2             2               2  0.949200  02:09:32
# 2  02:09:40              3             3               3  0.948200  02:09:40
# 3  02:09:49              4             4               4  0.947100  02:09:49
# 4  02:10:06              5             5               5  0.945000  02:10:06
#
#    AG_Place  Place_Diff  Year             Race
# 0         1           0  2009  Boston Marathon
# 1         2           0  2009  Boston Marathon
# 2         3           0  2009  Boston Marathon
# 3         4           0  2009  Boston Marathon
# 4         5           0  2009  Boston Marathon

# %%
boston.tail()
# Out:
#          Bib             Name  Age Gender          City  St  Cty      Pace  \
# 26651  23909   Mcninch, Brett   42      M   New Lebanon  OH  USA  00:16:34
# 26652  23949  Oconell, Justin   28      M      Franklin  MA  USA  00:16:39
# 26653  15946      Young, John   53      M         Salem  MA  USA  00:16:42
# 26654  23937    Smith, Denise   51      F  Fort Collins  CO  USA  00:17:01
# 26655  23958     Reilly, Bill   66      M   Kew Gardens  NY  USA  00:17:42
#
#            Time  Overall_Place  Gender_Place  Division_Place    AG_Pct  \
# 26651  07:14:12          26653         14672            1989  0.295455
# 26652  07:16:19          26654         14673            5092  0.281791
# 26653  07:17:35          26655         14674            1858  0.321924
# 26654  07:25:39          26656         11982            1200  0.349831
# 26655  07:43:48          26657         14675             469  0.343518
#
#                AG_Time  AG_Place  Place_Diff  Year             Race
# 26651  06:56:08.237000     26655          -2  2019  Boston Marathon
# 26652         07:16:19     26656          -2  2019  Boston Marathon
# 26653  06:21:55.364000     26648           7  2019  Boston Marathon
# 26654  06:27:05.495000     26650           6  2019  Boston Marathon
# 26655  05:57:54.868000     26565          92  2019  Boston Marathon

# %%
boston.plot(x ='Age', y='AG_Pct', kind = 'scatter')

# %%
boston_age_winners = boston[boston['Division_Place'] <= 1]
boston_age_winners.shape
# Out:
# (39, 18)

# %%
boston_age_winners.plot(x ='Age', y='AG_Pct', kind = 'scatter')

# %%
sns.lmplot(x='Age', y='AG_Pct', hue='Year', data=boston_age_winners, ci=None)

# %%
boston_age_winners.groupby(['Year']).mean()
# Out:
#             Age  Overall_Place  Gender_Place  Division_Place    AG_Pct  \
# Year
# 2009  56.421053    5481.684211   2573.894737             1.0  0.857091
# 2019  58.100000    6008.850000   2780.800000             1.0  0.897479
#
#         AG_Place   Place_Diff
# Year
# 2009  278.157895  5203.526316
# 2019  186.000000  5822.850000

# %%
boston_age_winners['AG_Pct'].describe()
# Out:
# count    39.000000
# mean      0.877803
# std       0.055317
# min       0.760400
# 25%       0.850103
# 50%       0.877723
# 75%       0.927597
# max       0.970156
# Name: AG_Pct, dtype: float64
